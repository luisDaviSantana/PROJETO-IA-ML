# %%
# CÉLULA TESTE - Rápida
print("Testando ambiente ML...")
import sys
print(f"Python: {sys.version.split()[0]}")

# Testar import principal
try:
    import sklearn
    print(f"Scikit-learn: {sklearn.__version__}")
except:
    print("Scikit-learn não encontrado")
# Out:
# Testando ambiente ML...
# Python: 3.13.7
# Scikit-learn: 1.7.2

# %%
# CÉLULA TESTE - Rápida
print("Testando ambiente ML...")
import sys
print(f"Python: {sys.version.split()[0]}")

# Testar import principal
try:
    import sklearn
    print(f"Scikit-learn: {sklearn.__version__}")
except:
    print("Scikit-learn não encontrado")
# Out:
# Testando ambiente ML...
# Python: 3.13.7
# Scikit-learn: 1.7.2
